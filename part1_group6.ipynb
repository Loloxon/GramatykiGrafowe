# %% [markdown]
# # Projekt 1 (Piątek) - Część 1 - Grupa 6
#
# Piotr Czarnik, Michał Szewc

# %%
import matplotlib
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
from graph.elements.edge import Edge
from graph.elements.hyperedge import HyperEdge
from graph.elements.node import Node
from graph.hypergraph import HyperGraph
from utils import visualize_hypergraph

# %%
from productions.p13 import P13
from productions.p14 import P14
from productions.p15 import P15

# %% [markdown]
# ## P13

# %%
P13().visualize()

# %% [markdown]
# ### Extended graph

# %%
nodes = [
    Node(0, 0, False),  # 1
    Node(1, 0, False),  # 2
    Node(1, 1, False),  # 3
    Node(0, 1, False),  # 4
    Node(1.5, 0.5, False),  # 5
    Node(0.5, 0, True),  # 6
    Node(0, 0.5, True),  # 7
    Node(0.5, 1, True),  # 8
    Node(-1, 1, False),  # 9
    Node(-1, 0.5, False),  # 10
    Node(-1, 0, False),  # 11
]

tested_hypergraph = HyperGraph(
    nodes=nodes,
    edges = [
        Edge(nodes[0], nodes[5], True),  # 1 - 6
        Edge(nodes[5], nodes[1], True),  # 6 - 2
        Edge(nodes[1], nodes[4], True),  # 2 - 5
        Edge(nodes[4], nodes[2], True),  # 5 - 3
        Edge(nodes[2], nodes[7], True),  # 3 - 8
        Edge(nodes[7], nodes[3], True),  # 8 - 4
        Edge(nodes[3], nodes[6], False),  # 4 - 7
        Edge(nodes[6], nodes[0], False),  # 7 - 1
        Edge(nodes[3], nodes[8], True),  # 4 - 9
        Edge(nodes[8], nodes[9], True),  # 9 - 10
        Edge(nodes[9], nodes[6], False),  # 10 - 7
        Edge(nodes[9], nodes[10], True),  # 10 - 11
        Edge(nodes[10], nodes[0], True),  # 11 - 1
    ],
    hyperedges = [
        HyperEdge(
            [nodes[0], nodes[1], nodes[4], nodes[2], nodes[3]], True, label="P"
        ),
        HyperEdge(
            [nodes[6], nodes[3], nodes[8], nodes[9]], True, label="Q"
        ),
        HyperEdge(
            [nodes[9], nodes[10], nodes[0], nodes[6]], True, label="Q"
        ),
    ]
)

visualize_hypergraph(
    tested_hypergraph.parse_hypergraph_to_networkx(),
    "Extended before P13", True, True, True, node_size=300, plot_size=(8, 8)
)

visualize_hypergraph(
    P13().apply(tested_hypergraph)[1].parse_hypergraph_to_networkx(),
    "Extended after P13", True, True, True, node_size=300, plot_size=(8, 8)
)

# %% [markdown]
# ### Invalid - missing node

# %%
nodes = [
    Node(0, 0, False),  # 1
    Node(1, 0, False),  # 2
    Node(1, 1, False),  # 3
    Node(0, 1, False),  # 4
    Node(1.5, 0.5, False),  # 5
    Node(0.5, 0, True),  # 6
    Node(0, 0.5, True),  # 7
]
edges = [
    Edge(nodes[0], nodes[5], True),  # 1 - 6
    Edge(nodes[5], nodes[1], True),  # 6 - 2
    Edge(nodes[1], nodes[4], True),  # 2 - 5
    Edge(nodes[4], nodes[2], True),  # 5 - 3
    Edge(nodes[2], nodes[3], True),  # 3 - 4
    Edge(nodes[3], nodes[6], True),  # 4 - 7
    Edge(nodes[6], nodes[0], True),  # 7 - 1
]
hyperedges = [
    HyperEdge(
        [nodes[0], nodes[1], nodes[4], nodes[2], nodes[3]], True, label="P"
    )
]

tested_hypergraph = HyperGraph(nodes, edges, hyperedges)

visualize_hypergraph(
    tested_hypergraph.parse_hypergraph_to_networkx(),
    "Invalid missing node before P13", True, True, True, node_size=300, plot_size=(8, 8)
)

visualize_hypergraph(
    P13().apply(tested_hypergraph)[1].parse_hypergraph_to_networkx(),
    "Invalid missing node after P13", True, True, True, node_size=300, plot_size=(8, 8)
)

# %% [markdown]
# ### Invalid - missing edge 1

# %%
nodes = [
    Node(0, 0, False),  # 1
    Node(1, 0, False),  # 2
    Node(1, 1, False),  # 3
    Node(0, 1, False),  # 4
    Node(1.5, 0.5, False),  # 5
    Node(0.5, 0, True),  # 6
    Node(0, 0.5, True),  # 7
    Node(0.5, 1, True),  # 8
]
edges = [
    Edge(nodes[0], nodes[5], True),  # 1 - 6
    Edge(nodes[5], nodes[1], True),  # 6 - 2
    Edge(nodes[1], nodes[4], True),  # 2 - 5
    Edge(nodes[4], nodes[2], True),  # 5 - 3
    Edge(nodes[2], nodes[7], True),  # 3 - 8
    Edge(nodes[7], nodes[3], True),  # 8 - 4
    Edge(nodes[3], nodes[6], True),  # 4 - 7
]
hyperedges = [
    HyperEdge(
        [nodes[0], nodes[1], nodes[4], nodes[2], nodes[3]], True, label="P"
    )
]

tested_hypergraph = HyperGraph(nodes, edges, hyperedges)

visualize_hypergraph(
    tested_hypergraph.parse_hypergraph_to_networkx(),
    "Invalid missing edge 1 before P13", True, True, True, node_size=300, plot_size=(8, 8)
)

visualize_hypergraph(
    P13().apply(tested_hypergraph)[1].parse_hypergraph_to_networkx(),
    "Invalid missing edge 1 after P13", True, True, True, node_size=300, plot_size=(8, 8)
)

# %% [markdown]
# ### Invalid - missing edge 2

# %%
nodes = [
    Node(0, 0, False),  # 1
    Node(1, 0, False),  # 2
    Node(1, 1, False),  # 3
    Node(0, 1, False),  # 4
    Node(1.5, 0.5, False),  # 5
    Node(0.5, 0, True),  # 6
    Node(0, 0.5, True),  # 7
    Node(0.5, 1, True),  # 8
]
edges = [
    Edge(nodes[0], nodes[5], True),  # 1 - 6
    Edge(nodes[5], nodes[1], True),  # 6 - 2
    Edge(nodes[1], nodes[4], True),  # 2 - 5
    Edge(nodes[2], nodes[7], True),  # 3 - 8
    Edge(nodes[7], nodes[3], True),  # 8 - 4
    Edge(nodes[3], nodes[6], True),  # 4 - 7
    Edge(nodes[6], nodes[0], True),  # 7 - 1
]
hyperedges = [
    HyperEdge(
        [nodes[0], nodes[1], nodes[4], nodes[2], nodes[3]], True, label="P"
    )
]


visualize_hypergraph(
    tested_hypergraph.parse_hypergraph_to_networkx(),
    "Invalid missing edge 2 before P13", True, True, True, node_size=300, plot_size=(8, 8)
)

visualize_hypergraph(
    P13().apply(tested_hypergraph)[1].parse_hypergraph_to_networkx(),
    "Invalid missing edge 2 after P13", True, True, True, node_size=300, plot_size=(8, 8)
)

# %% [markdown]
# ### Invalid - missing edge 3

# %%
nodes = [
    Node(0, 0, False),  # 1
    Node(1, 0, False),  # 2
    Node(1, 1, False),  # 3
    Node(0, 1, False),  # 4
    Node(1.5, 0.5, False),  # 5
    Node(0.5, 0, True),  # 6
    Node(0, 0.5, True),  # 7
    Node(0.5, 1, True),  # 8
]
edges = [
    Edge(nodes[0], nodes[5], True),  # 1 - 6
    Edge(nodes[1], nodes[4], True),  # 2 - 5
    Edge(nodes[4], nodes[2], True),  # 5 - 3
    Edge(nodes[2], nodes[7], True),  # 3 - 8
    Edge(nodes[7], nodes[3], True),  # 8 - 4
    Edge(nodes[3], nodes[6], True),  # 4 - 7
    Edge(nodes[6], nodes[0], True),  # 7 - 1
]
hyperedges = [
    HyperEdge(
        [nodes[0], nodes[1], nodes[4], nodes[2], nodes[3]], True, label="P"
    )
]
tested_hypergraph = HyperGraph(nodes, edges, hyperedges)
visualize_hypergraph(
    tested_hypergraph.parse_hypergraph_to_networkx(),
    "Invalid missing edge 3 before P13", True, True, True, node_size=300, plot_size=(8, 8)
)

visualize_hypergraph(
    P13().apply(tested_hypergraph)[1].parse_hypergraph_to_networkx(),
    "Invalid missing edge 3 after P13", True, True, True, node_size=300, plot_size=(8, 8)
)

# %% [markdown]
# ### Invalid label

# %%
nodes = [
    Node(0, 0, False),  # 1
    Node(1, 0, False),  # 2
    Node(1, 1, False),  # 3
    Node(0, 1, False),  # 4
    Node(1.5, 0.5, False),  # 5
    Node(0.5, 0, True),  # 6
    Node(0, 0.5, True),  # 7
    Node(0.5, 1, True, label='A'),  # 8
]
edges = [
    Edge(nodes[0], nodes[5], True),  # 1 - 6
    Edge(nodes[5], nodes[1], True),  # 6 - 2
    Edge(nodes[1], nodes[4], True),  # 2 - 5
    Edge(nodes[4], nodes[2], True),  # 5 - 3
    Edge(nodes[2], nodes[7], True),  # 3 - 8
    Edge(nodes[7], nodes[3], True),  # 8 - 4
    Edge(nodes[3], nodes[6], True),  # 4 - 7
    Edge(nodes[6], nodes[0], True),  # 7 - 1
]
hyperedges = [
    HyperEdge(
        [nodes[0], nodes[1], nodes[4], nodes[2], nodes[3]], True, label="P"
    )
]
tested_hypergraph = HyperGraph(nodes, edges, hyperedges)

visualize_hypergraph(
    tested_hypergraph.parse_hypergraph_to_networkx(),
    "Invalid label before P13", True, True, True, node_size=300, plot_size=(8, 8)
)

visualize_hypergraph(
    P13().apply(tested_hypergraph)[1].parse_hypergraph_to_networkx(),
    "Invalid label after P13", True, True, True, node_size=300, plot_size=(8, 8)
)

# %% [markdown]
# ## P14

# %%
P14().visualize()

# %% [markdown]
# ### Extended

# %%
nodes = [
    Node(0, 0, False),  # 1
    Node(1, 0, False),  # 2
    Node(1, 1, False),  # 3
    Node(0, 1, False),  # 4
    Node(1.5, 0.5, False),  # 5
    Node(0.5, 0, True),  # 6
    Node(0, 0.5, True),  # 7
    Node(0.5, 1, True),  # 8
    Node(1.25, 0.75, True),  # 9
    Node(-1, 1, False),  # 10
    Node(-1, 0.5, False),  # 11
    Node(-1, 0, False),  # 12
]
edges = [
    Edge(nodes[0], nodes[5], True),  # 1 - 6
    Edge(nodes[5], nodes[1], True),  # 6 - 2
    Edge(nodes[1], nodes[4], True),  # 2 - 5
    Edge(nodes[4], nodes[8], True),  # 5 - 9
    Edge(nodes[8], nodes[2], True),  # 9 - 3
    Edge(nodes[2], nodes[7], True),  # 3 - 8
    Edge(nodes[7], nodes[3], True),  # 8 - 4
    Edge(nodes[3], nodes[6], False),  # 4 - 7
    Edge(nodes[6], nodes[0], False),  # 7 - 1
    Edge(nodes[3], nodes[9], True),  # 4 - 10
    Edge(nodes[9], nodes[10], True),  # 10 - 11
    Edge(nodes[10], nodes[6], False),  # 11 - 7
    Edge(nodes[10], nodes[11], True),  # 11 - 12
    Edge(nodes[11], nodes[0], True),  # 12 - 1
]
hyperedges = [
    HyperEdge(
        [nodes[0], nodes[1], nodes[4], nodes[2], nodes[3]], True, label="P"
    ),
    HyperEdge(
        [nodes[6], nodes[3], nodes[9], nodes[10]], True, label="Q"
    ),
    HyperEdge(
        [nodes[10], nodes[11], nodes[0], nodes[6]], True, label="Q"
    ),
]
tested_hypergraph = HyperGraph(nodes, edges, hyperedges)

visualize_hypergraph(
    tested_hypergraph.parse_hypergraph_to_networkx(),
    "Extended before P14", True, True, True, node_size=300, plot_size=(8, 8)
)

visualize_hypergraph(
    P14().apply(tested_hypergraph)[1].parse_hypergraph_to_networkx(),
    "Extended after P14", True, True, True, node_size=300, plot_size=(8, 8)
)

# %% [markdown]
# ### Invalid missing node

# %%
nodes = [
    Node(0, 0, False),  # 1
    Node(1, 0, False),  # 2
    Node(1, 1, False),  # 3
    Node(0, 1, False),  # 4
    Node(1.5, 0.5, False),  # 5
    Node(0.5, 0, True),  # 6
    Node(0, 0.5, True),  # 7
    Node(0.5, 1, True),  # 8
]
edges = [
    Edge(nodes[0], nodes[5], True),  # 1 - 6
    Edge(nodes[5], nodes[1], True),  # 6 - 2
    Edge(nodes[1], nodes[4], True),  # 2 - 5
    Edge(nodes[4], nodes[2], True),  # 5 - 3
    Edge(nodes[2], nodes[7], True),  # 3 - 8
    Edge(nodes[7], nodes[3], True),  # 8 - 4
    Edge(nodes[3], nodes[6], True),  # 4 - 7
    Edge(nodes[6], nodes[0], True),  # 7 - 1
]
hyperedges = [
    HyperEdge(
        [nodes[0], nodes[1], nodes[4], nodes[2], nodes[3]], True, label="P"
    )
]

tested_hypergraph = HyperGraph(nodes, edges, hyperedges)

visualize_hypergraph(
    tested_hypergraph.parse_hypergraph_to_networkx(),
    "Invalid missing node before P14", True, True, True, node_size=300, plot_size=(8, 8)
)

visualize_hypergraph(
    P14().apply(tested_hypergraph)[1].parse_hypergraph_to_networkx(),
    "Invalid missing node after P14", True, True, True, node_size=300, plot_size=(8, 8)
)

# %% [markdown]
# ### Invalid - missing edge 1

# %%
nodes = [
    Node(0, 0, False),  # 1
    Node(1, 0, False),  # 2
    Node(1, 1, False),  # 3
    Node(0, 1, False),  # 4
    Node(1.5, 0.5, False),  # 5
    Node(0.5, 0, True),  # 6
    Node(0, 0.5, True),  # 7
    Node(0.5, 1, True),  # 8
    Node(1.25, 0.75, True),  # 9
]
edges = [
    Edge(nodes[0], nodes[5], True),  # 1 - 6
    Edge(nodes[5], nodes[1], True),  # 6 - 2
    Edge(nodes[1], nodes[4], True),  # 2 - 5
    Edge(nodes[4], nodes[8], True),  # 5 - 9
    Edge(nodes[8], nodes[2], True),  # 9 - 3
    Edge(nodes[2], nodes[7], True),  # 3 - 8
    Edge(nodes[7], nodes[3], True),  # 8 - 4
    Edge(nodes[3], nodes[6], True),  # 4 - 7
]
hyperedges = [
    HyperEdge(
        [nodes[0], nodes[1], nodes[4], nodes[2], nodes[3]], True, label="P"
    )
]

tested_hypergraph = HyperGraph(nodes, edges, hyperedges)

visualize_hypergraph(
    tested_hypergraph.parse_hypergraph_to_networkx(),
    "Invalid missing edge 1 before P14", True, True, True, node_size=300, plot_size=(8, 8)
)

visualize_hypergraph(
    P14().apply(tested_hypergraph)[1].parse_hypergraph_to_networkx(),
    "Invalid missing edge 1 after P14", True, True, True, node_size=300, plot_size=(8, 8)
)

# %% [markdown]
# ### Invalid - missing edge 2

# %%
nodes = [
    Node(0, 0, False),  # 1
    Node(1, 0, False),  # 2
    Node(1, 1, False),  # 3
    Node(0, 1, False),  # 4
    Node(1.5, 0.5, False),  # 5
    Node(0.5, 0, True),  # 6
    Node(0, 0.5, True),  # 7
    Node(0.5, 1, True),  # 8
    Node(1.25, 0.75, True),  # 9
]
edges = [
    Edge(nodes[0], nodes[5], True),  # 1 - 6
    Edge(nodes[5], nodes[1], True),  # 6 - 2
    Edge(nodes[1], nodes[4], True),  # 2 - 5
    Edge(nodes[4], nodes[8], True),  # 5 - 9
    Edge(nodes[2], nodes[7], True),  # 3 - 8
    Edge(nodes[7], nodes[3], True),  # 8 - 4
    Edge(nodes[3], nodes[6], True),  # 4 - 7
    Edge(nodes[6], nodes[0], True),  # 7 - 1
]
hyperedges = [
    HyperEdge(
        [nodes[0], nodes[1], nodes[4], nodes[2], nodes[3]], True, label="P"
    )
]

tested_hypergraph = HyperGraph(nodes, edges, hyperedges)

visualize_hypergraph(
    tested_hypergraph.parse_hypergraph_to_networkx(),
    "Invalid missing edge 2 before P14", True, True, True, node_size=300, plot_size=(8, 8)
)

visualize_hypergraph(
    P14().apply(tested_hypergraph)[1].parse_hypergraph_to_networkx(),
    "Invalid missing edge 2 after P14", True, True, True, node_size=300, plot_size=(8, 8)
)

# %% [markdown]
# ### Invalid - missing edge 3

# %%
nodes = [
    Node(0, 0, False),  # 1
    Node(1, 0, False),  # 2
    Node(1, 1, False),  # 3
    Node(0, 1, False),  # 4
    Node(1.5, 0.5, False),  # 5
    Node(0.5, 0, True),  # 6
    Node(0, 0.5, True),  # 7
    Node(0.5, 1, True),  # 8
    Node(1.25, 0.75, True),  # 9
]
edges = [
    Edge(nodes[0], nodes[5], True),  # 1 - 6
    Edge(nodes[5], nodes[1], True),  # 6 - 2
    Edge(nodes[4], nodes[8], True),  # 5 - 9
    Edge(nodes[8], nodes[2], True),  # 9 - 3
    Edge(nodes[2], nodes[7], True),  # 3 - 8
    Edge(nodes[7], nodes[3], True),  # 8 - 4
    Edge(nodes[3], nodes[6], True),  # 4 - 7
    Edge(nodes[6], nodes[0], True),  # 7 - 1
]
hyperedges = [
    HyperEdge(
        [nodes[0], nodes[1], nodes[4], nodes[2], nodes[3]], True, label="P"
    )
]

tested_hypergraph = HyperGraph(nodes, edges, hyperedges)

visualize_hypergraph(
    tested_hypergraph.parse_hypergraph_to_networkx(),
    "Invalid missing edge 3 before P14", True, True, True, node_size=300, plot_size=(8, 8)
)

visualize_hypergraph(
    P14().apply(tested_hypergraph)[1].parse_hypergraph_to_networkx(),
    "Invalid missing edge 3 after P14", True, True, True, node_size=300, plot_size=(8, 8)
)

# %% [markdown]
# ### Invalid label

# %%
nodes = [
    Node(0, 0, False),  # 1
    Node(1, 0, False),  # 2
    Node(1, 1, False),  # 3
    Node(0, 1, False, label="L"),  # 4
    Node(1.5, 0.5, False),  # 5
    Node(0.5, 0, True),  # 6
    Node(0, 0.5, True),  # 7
    Node(0.5, 1, True),  # 8
    Node(1.25, 0.75, True),  # 9
]
edges = [
    Edge(nodes[0], nodes[5], True),  # 1 - 6
    Edge(nodes[5], nodes[1], True),  # 6 - 2
    Edge(nodes[1], nodes[4], True),  # 2 - 5
    Edge(nodes[4], nodes[8], True),  # 5 - 9
    Edge(nodes[8], nodes[2], True),  # 9 - 3
    Edge(nodes[2], nodes[7], True),  # 3 - 8
    Edge(nodes[7], nodes[3], True),  # 8 - 4
    Edge(nodes[3], nodes[6], True),  # 4 - 7
    Edge(nodes[6], nodes[0], True),  # 7 - 1
]
hyperedges = [
    HyperEdge(
        [nodes[0], nodes[1], nodes[4], nodes[2], nodes[3]], True, label="P"
    )
]
tested_hypergraph = HyperGraph(nodes, edges, hyperedges)
visualize_hypergraph(
    tested_hypergraph.parse_hypergraph_to_networkx(),
    "Invalid label before P14", True, True, True, node_size=300, plot_size=(8, 8)
)

visualize_hypergraph(
    P14().apply(tested_hypergraph)[1].parse_hypergraph_to_networkx(),
    "Invalid label after P14", True, True, True, node_size=300, plot_size=(8, 8)
)

# %% [markdown]
# ## P15

# %%
P15().visualize()

# %% [markdown]
# ### Extended

# %%
nodes = [
    Node(0, 0, False),  # 1
    Node(1, 0, False),  # 2
    Node(1, 1, False),  # 3
    Node(0, 1, False),  # 4
    Node(1.5, 0.5, False),  # 5
    Node(0.5, 0, True),  # 6
    Node(0, 0.5, True),  # 7
    Node(0.5, 1, True),  # 8
    Node(1.25, 0.75, True),  # 9
    Node(1.25, 0.25, True),  # 10

    Node(-1, 1, False),  # 11
    Node(-1, 0.5, False),  # 12
    Node(-1, 0, False),  # 13
]
edges = [
    Edge(nodes[0], nodes[5], True),  # 1 - 6
    Edge(nodes[5], nodes[1], True),  # 6 - 2
    Edge(nodes[1], nodes[9], True),  # 2 - 10
    Edge(nodes[9], nodes[4], True),  # 10 - 5
    Edge(nodes[4], nodes[8], True),  # 5 - 9
    Edge(nodes[8], nodes[2], True),  # 9 - 3
    Edge(nodes[2], nodes[7], True),  # 3 - 8
    Edge(nodes[7], nodes[3], True),  # 8 - 4
    Edge(nodes[3], nodes[6], False),  # 4 - 7
    Edge(nodes[6], nodes[0], False),  # 7 - 1

    Edge(nodes[3], nodes[10], True),  # 4 - 11
    Edge(nodes[10], nodes[11], True),  # 11 - 12
    Edge(nodes[11], nodes[6], False),  # 12 - 7
    Edge(nodes[11], nodes[12], True),  # 12 - 13
    Edge(nodes[12], nodes[0], True),  # 13 - 1
]
hyperedges = [
    HyperEdge(
        [nodes[0], nodes[1], nodes[4], nodes[2], nodes[3]], True, label="P"
    ),
    HyperEdge(
        [nodes[6], nodes[3], nodes[10], nodes[11]], True, label="Q"
    ),
    HyperEdge(
        [nodes[11], nodes[12], nodes[0], nodes[6]], True, label="Q"
    ),
]
tested_hypergraph = HyperGraph(nodes, edges, hyperedges)

visualize_hypergraph(
    tested_hypergraph.parse_hypergraph_to_networkx(),
    "Extended before P15", True, True, True, node_size=300, plot_size=(8, 8)
)

visualize_hypergraph(
    P15().apply(tested_hypergraph)[1].parse_hypergraph_to_networkx(),
    "Extended after P15", True, True, True, node_size=300, plot_size=(8, 8)
)

# %% [markdown]
# ### Invalid - missing node

# %%
nodes = [
    Node(0, 0, False),  # 1
    Node(1, 0, False),  # 2
    Node(1, 1, False),  # 3
    Node(0, 1, False),  # 4
    Node(1.5, 0.5, False),  # 5
    Node(0.5, 0, True),  # 6
    Node(0, 0.5, True),  # 7
    Node(0.5, 1, True),  # 8
    Node(1.25, 0.75, True),  # 9
]
edges = [
    Edge(nodes[0], nodes[5], True),  # 1 - 6
    Edge(nodes[5], nodes[1], True),  # 6 - 2
    Edge(nodes[1], nodes[4], True),  # 2 - 5
    Edge(nodes[4], nodes[8], True),  # 5 - 9
    Edge(nodes[8], nodes[2], True),  # 9 - 3
    Edge(nodes[2], nodes[7], True),  # 3 - 8
    Edge(nodes[7], nodes[3], True),  # 8 - 4
    Edge(nodes[3], nodes[6], True),  # 4 - 7
    Edge(nodes[6], nodes[0], True),  # 7 - 1
]
hyperedges = [
    HyperEdge(
        [nodes[0], nodes[1], nodes[4], nodes[2], nodes[3]], True, label="P"
    )
]

tested_hypergraph = HyperGraph(nodes, edges, hyperedges)

visualize_hypergraph(
    tested_hypergraph.parse_hypergraph_to_networkx(),
    "Invalid missing node before P15", True, True, True, node_size=300, plot_size=(8, 8)
)

visualize_hypergraph(
    P15().apply(tested_hypergraph)[1].parse_hypergraph_to_networkx(),
    "Invalid missing node after P15", True, True, True, node_size=300, plot_size=(8, 8)
)

# %% [markdown]
# ### Invalid - missing edge 1

# %%
nodes = [
    Node(0, 0, False),  # 1
    Node(1, 0, False),  # 2
    Node(1, 1, False),  # 3
    Node(0, 1, False),  # 4
    Node(1.5, 0.5, False),  # 5
    Node(0.5, 0, True),  # 6
    Node(0, 0.5, True),  # 7
    Node(0.5, 1, True),  # 8
    Node(1.25, 0.75, True),  # 9
    Node(1.25, 0.25, True),  # 10
]
edges = [
    Edge(nodes[0], nodes[5], True),  # 1 - 6
    Edge(nodes[5], nodes[1], True),  # 6 - 2
    Edge(nodes[1], nodes[9], True),  # 2 - 10
    Edge(nodes[9], nodes[4], True),  # 10 - 5
    Edge(nodes[4], nodes[8], True),  # 5 - 9
    Edge(nodes[8], nodes[2], True),  # 9 - 3
    Edge(nodes[2], nodes[7], True),  # 3 - 8
    Edge(nodes[7], nodes[3], True),  # 8 - 4
    Edge(nodes[3], nodes[6], True),  # 4 - 7
]
hyperedges = [
    HyperEdge(
        [nodes[0], nodes[1], nodes[4], nodes[2], nodes[3]], True, label="P"
    )
]
tested_hypergraph = HyperGraph(nodes, edges, hyperedges)

visualize_hypergraph(
    tested_hypergraph.parse_hypergraph_to_networkx(),
    "Invalid missing edge 1 before P15", True, True, True, node_size=300, plot_size=(8, 8)
)

visualize_hypergraph(
    P15().apply(tested_hypergraph)[1].parse_hypergraph_to_networkx(),
    "Invalid missing edge 1 after P15", True, True, True, node_size=300, plot_size=(8, 8)
)

# %% [markdown]
# ### Invalid - missing edge 2

# %%
nodes = [
    Node(0, 0, False),  # 1
    Node(1, 0, False),  # 2
    Node(1, 1, False),  # 3
    Node(0, 1, False),  # 4
    Node(1.5, 0.5, False),  # 5
    Node(0.5, 0, True),  # 6
    Node(0, 0.5, True),  # 7
    Node(0.5, 1, True),  # 8
    Node(1.25, 0.75, True),  # 9
    Node(1.25, 0.25, True),  # 10
]
edges = [
    Edge(nodes[0], nodes[5], True),  # 1 - 6
    Edge(nodes[5], nodes[1], True),  # 6 - 2
    Edge(nodes[1], nodes[9], True),  # 2 - 10
    Edge(nodes[9], nodes[4], True),  # 10 - 5
    Edge(nodes[4], nodes[8], True),  # 5 - 9
    Edge(nodes[8], nodes[2], True),  # 9 - 3
    Edge(nodes[2], nodes[7], True),  # 3 - 8
    Edge(nodes[3], nodes[6], True),  # 4 - 7
    Edge(nodes[6], nodes[0], True),  # 7 - 1
]
hyperedges = [
    HyperEdge(
        [nodes[0], nodes[1], nodes[4], nodes[2], nodes[3]], True, label="P"
    )
]
tested_hypergraph = HyperGraph(nodes, edges, hyperedges)

visualize_hypergraph(
    tested_hypergraph.parse_hypergraph_to_networkx(),
    "Invalid missing edge 2 before P15", True, True, True, node_size=300, plot_size=(8, 8)
)

visualize_hypergraph(
    P15().apply(tested_hypergraph)[1].parse_hypergraph_to_networkx(),
    "Invalid missing edge 2 after P15", True, True, True, node_size=300, plot_size=(8, 8)
)

# %% [markdown]
# ### Invalid - missing edge 3

# %%
nodes = [
    Node(0, 0, False),  # 1
    Node(1, 0, False),  # 2
    Node(1, 1, False),  # 3
    Node(0, 1, False),  # 4
    Node(1.5, 0.5, False),  # 5
    Node(0.5, 0, True),  # 6
    Node(0, 0.5, True),  # 7
    Node(0.5, 1, True),  # 8
    Node(1.25, 0.75, True),  # 9
    Node(1.25, 0.25, True),  # 10
]
edges = [
    Edge(nodes[5], nodes[1], True),  # 6 - 2
    Edge(nodes[1], nodes[9], True),  # 2 - 10
    Edge(nodes[9], nodes[4], True),  # 10 - 5
    Edge(nodes[4], nodes[8], True),  # 5 - 9
    Edge(nodes[8], nodes[2], True),  # 9 - 3
    Edge(nodes[2], nodes[7], True),  # 3 - 8
    Edge(nodes[7], nodes[3], True),  # 8 - 4
    Edge(nodes[3], nodes[6], True),  # 4 - 7
    Edge(nodes[6], nodes[0], True),  # 7 - 1
]
hyperedges = [
    HyperEdge(
        [nodes[0], nodes[1], nodes[4], nodes[2], nodes[3]], True, label="P"
    )
]
tested_hypergraph = HyperGraph(nodes, edges, hyperedges)

visualize_hypergraph(
    tested_hypergraph.parse_hypergraph_to_networkx(),
    "Invalid missing edge 3 before P15", True, True, True, node_size=300, plot_size=(8, 8)
)

visualize_hypergraph(
    P15().apply(tested_hypergraph)[1].parse_hypergraph_to_networkx(),
    "Invalid missing edge 3 after P15", True, True, True, node_size=300, plot_size=(8, 8)
)

# %% [markdown]
# ### Invalid label

# %%
nodes = [
    Node(0, 0, False),  # 1
    Node(1, 0, False),  # 2
    Node(1, 1, False),  # 3
    Node(0, 1, False),  # 4
    Node(1.5, 0.5, False),  # 5
    Node(0.5, 0, True),  # 6
    Node(0, 0.5, True),  # 7
    Node(0.5, 1, True),  # 8
    Node(1.25, 0.75, True),  # 9
    Node(1.25, 0.25, True, label='A'),  # 10
]
edges = [
    Edge(nodes[0], nodes[5], True),  # 1 - 6
    Edge(nodes[5], nodes[1], True),  # 6 - 2
    Edge(nodes[1], nodes[9], True),  # 2 - 10
    Edge(nodes[9], nodes[4], True),  # 10 - 5
    Edge(nodes[4], nodes[8], True),  # 5 - 9
    Edge(nodes[8], nodes[2], True),  # 9 - 3
    Edge(nodes[2], nodes[7], True),  # 3 - 8
    Edge(nodes[7], nodes[3], True),  # 8 - 4
    Edge(nodes[3], nodes[6], True),  # 4 - 7
    Edge(nodes[6], nodes[0], True),  # 7 - 1
]
hyperedges = [
    HyperEdge(
        [nodes[0], nodes[1], nodes[4], nodes[2], nodes[3]], True, label="P"
    )
]
tested_hypergraph = HyperGraph(nodes, edges, hyperedges)

visualize_hypergraph(
    tested_hypergraph.parse_hypergraph_to_networkx(),
    "Invalid label before P15", True, True, True, node_size=300, plot_size=(8, 8)
)

visualize_hypergraph(
    P15().apply(tested_hypergraph)[1].parse_hypergraph_to_networkx(),
    "Invalid label after P15", True, True, True, node_size=300, plot_size=(8, 8)
)
